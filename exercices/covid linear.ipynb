# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
# data = r'C:\Users\alaja\simplon_datai_2025\1\reduced_covid_sexe.csv'
data = pd.read_csv(r'C:\Users\alaja\simplon_datai_2025\1\reduced_covid_sexe.csv')

# meta = pd.read_csv(metacsv, sep = ';', encoding="latin-1")

# dataframe = pd.read_csv(data, sep = ';')
# dataframe

# %%
dct = data[2:]["dc"]
dch = data[2:]["dc.1"]
dcf = data[2:]["dc.2"]
hospt = data[2:]["hosp"]
hosph = data[2:]["hosp.1"]
hospf = data[2:]["hosp.2"]
date = data[2:]["Unnamed: 0"]
index = data.index[2:]
index.shape
# Out:
# (1109,)

# %%
sizes = np.random.uniform(15, 80, len(dct))
colors = np.random.uniform(15, 80, len(dct))
# sizes = np.random.uniform(15, 80, len(hospt))
# colors = np.random.uniform(15, 80, len(hospt))

plt.scatter(index, dct, s=sizes, c=colors, vmin=0, vmax=100, label = 'dct')
# plt.scatter(date, hospt, s=sizes, c=colors, vmin=0, vmax=100, label = 'hospt')

# %%
dct_train, dct_test, index_train, index_test = train_test_split(
    dct, index)

# %%
plt.scatter(index_train, dct_train, label = 'train')
plt.scatter(index_test, dct_test, label = 'test')
plt.legend()

# %%
index_test.shape
# Out:
# (278,)

# %%
dct_test.shape
# Out:
# (278,)

# %%
dct_train = dct_train.to_numpy().reshape(-1, 1)
dct_test = dct_test.to_numpy().reshape(-1, 1)
dct_train.shape
# Out:
# (831, 1)

# %%
regr = LinearRegression()
regr.fit(dct_train, index_train)
print(regr.score(dct_test, index_test))
# Out:
# 0.9546938190559943

# %%
y_pred = regr.predict(dct_test)

# plt.scatter(X_train, y_train, color ='b')
plt.scatter(index_train, dct_train, label = 'train')

# plt.plot(X_test, y_pred, color ='k')
plt.plot(y_pred, dct_test, label = 'prediction', color ='k')
plt.legend()
plt.show()

# %%
# Import the necessary modules and libraries
import matplotlib.pyplot as plt
import numpy as np

from sklearn.tree import DecisionTreeRegressor

# Create a random dataset
rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 3 * (0.5 - rng.rand(16))

# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X, y)
regr_2.fit(X, y)

# Predict
X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# Plot the results
plt.figure()
plt.scatter(X, y, s=20, edgecolor="black", c="darkorange", label="data")
plt.plot(X_test, y_1, color="cornflowerblue", label="max_depth=2", linewidth=2)
plt.plot(X_test, y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()

# %%
y_pred = regr.predict(dct_test)

# plt.scatter(X_train, y_train, color ='b')
plt.scatter(index_train, dct_train, label = 'train')

# plt.plot(X_test, y_pred, color ='k')
plt.plot(y_pred, dct_test, label = 'prediction', color ='k')
plt.legend()
plt.show()

# %%
dct = dct.to_numpy().reshape(-1, 1)
index = index.to_numpy().reshape(-1, 1)

# %%
# index_train = index_train.to_numpy()
# index_test = index_test.to_numpy()

# %%
# index_train = index_train.reshape(-1, 1)
# index_test = index_test.reshape(-1, 1)

# %%
# y_pred = regr.predict(dct_test)
# # Fit regression model
# ypred2 = y_pred.DecisionTreeRegressor()


# # Predict
# x_1 = regr_1.predict(dct_test)

# # Plot the results
# plt.figure()
# plt.scatter(index, dct, s=20, edgecolor="black", c="darkorange", label="morts")
# plt.scatter(ypred2, x_1, color="cornflowerblue", label="max_depth=3", linewidth=2)
# plt.xlabel("morts")
# plt.ylabel("jours")
# plt.title("Decision Tree Regression")
# plt.legend()
# plt.show()

# %%
print(index)
# Out:
# [[   2]
#  [   3]
#  [   4]
#  ...
#  [1108]
#  [1109]
#  [1110]]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import numpy as np

# Divisez les données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(index, dct)

# Créez un modèle de régression par arbre de décision
regressor = DecisionTreeRegressor(max_leaf_nodes=3)
regr_1 = DecisionTreeRegressor(max_leaf_nodes=5)
regr_2 = DecisionTreeRegressor(max_leaf_nodes=10)

# Entraînez le modèle
regressor.fit(X_train, y_train)
regr_1.fit(X_train, y_train)
regr_2.fit(X_train, y_train)

# Faites des prédictions sur l'ensemble de test
y_pred = regressor.predict(X_test)
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# Évaluez les performances du modèle
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

plt.scatter(index, dct, c='k', label="data")
# plt.scatter(y_train, X_train, label = 'train', color ='r')
# plt.scatter(y_test, X_test, label = 'test', color ='g')
plt.scatter(X_test, y_pred, label = 'leaf 3', color ='g')
plt.scatter(X_test, y_1, label = 'leaf 5', color ='b')
# plt.plot(y_2, X_test, color="yellowgreen", label="max_depth=10", linewidth=2)
# plt.scatter(X_test, y_2, label = 'leaf 10', color ='r')
plt.legend()

print(f'Mean Squared Error (MSE): {mse}')
print(f'R-squared (R2): {r2}')
# Out:
# Mean Squared Error (MSE): 147637424.81757054
# R-squared (R2): 0.9151388315360469

# %% [markdown]
# leaf 3

# %%
thresholds3 = regressor.tree_.threshold
features3 = regressor.tree_.feature
plt.scatter(features3, thresholds3, c='k', label="data")

# %%
thresholds.make_pipeline()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\alaja\simplon_datai_2025\exercices\covid linear.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/alaja/simplon_datai_2025/exercices/covid%20linear.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> thresholds.make_pipeline()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'make_pipeline'

# %%
my_list = [x for x in thresholds3 if x >= 0]
my_list.sort()
my_list
# Out:
# [378.0, 694.5]

# %%
liste1 = my_list.range()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\alaja\simplon_datai_2025\exercices\covid linear.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/alaja/simplon_datai_2025/exercices/covid%20linear.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> liste1 = my_list.range()
#
# AttributeError: 'list' object has no attribute 'range'

# %% [markdown]
# afficher les statistiques descriptives des données

# %%
.describe()
# Out:
#   Cell In[23], line 1
#     .describe()
#     ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer


def _generate_vector(shift=0.5, noise=15):
    return np.arange(1000) + (np.random.rand(1000) - shift) * noise


def generate_dataset():
    """
    This dataset is two lines with a slope ~ 1, where one has
    a y offset of ~100
    """
    return np.vstack((
        np.vstack((
            _generate_vector(),
            _generate_vector() + 100,
        )).T,
        np.vstack((
            _generate_vector(),
            _generate_vector(),
        )).T,
    )), np.hstack((np.zeros(1000), np.ones(1000)))


def all_but_first_column(X):
    return X[:, 1:]


def drop_first_component(X, y):
    """
    Create a pipeline with PCA and the column selector and use it to
    transform the dataset.
    """
    pipeline = make_pipeline(
        PCA(), FunctionTransformer(all_but_first_column),
    )
    X_train, X_test, y_train, y_test = train_test_split(X, y)
    pipeline.fit(X_train, y_train)
    return pipeline.transform(X_test), y_test


if __name__ == '__main__':
    X, y = generate_dataset()
    lw = 0
    plt.figure()
    plt.scatter(X[:, 0], X[:, 1], c=y, lw=lw)
    plt.figure()
    X_transformed, y_transformed = drop_first_component(*generate_dataset())
    plt.scatter(
        X_transformed[:, 0],
        np.zeros(len(X_transformed)),
        c=y_transformed,
        lw=lw,
        s=60
    )
    plt.show()
