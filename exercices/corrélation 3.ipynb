# %% [markdown]
# two gaussian distributed data with different mean and variance (play with the parameters)

# %%
import numpy as np
import matplotlib.pyplot as plt
moyenne_x = 0
ecart_type_x = 1
moyenne_y = 1
ecart_type_y = 2

x = np.linspace(-5,5, 1000)

gaussiennex = (1 / (ecart_type_x * np.sqrt(2 * np.pi))) * np.exp(-(x - moyenne_x)**2 / (2 * ecart_type_x**2))
gaussienney = (1 / (ecart_type_y * np.sqrt(2 * np.pi))) * np.exp(-(y - moyenne_y)**2 / (2 * ecart_type_y**2))
plt.plot(x, gaussiennex)
plt.plot(y, gaussienney)
plt.show()
